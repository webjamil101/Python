# %% [markdown]
# **3021. Alice and Bob Playing Flower Game**
#
# **Medium**
#
# **Companies**
#
# Alice and Bob are playing a turn-based game on a field, with two lanes of flowers between them. There are x flowers in the first lane between Alice and Bob, and y flowers in the second lane between them.
#
# The game proceeds as follows:
#
# Alice takes the first turn.
# In each turn, a player must choose either one of the lane and pick one flower from that side.
# At the end of the turn, if there are no flowers left at all in either lane, the current player captures their opponent and wins the game.
# Given two integers, n and m, the task is to compute the number of possible pairs (x, y) that satisfy the conditions:
#
# Alice must win the game according to the described rules.
# The number of flowers x in the first lane must be in the range [1,n].
# The number of flowers y in the second lane must be in the range [1,m].
# Return the number of possible pairs (x, y) that satisfy the conditions mentioned in the statement.
#
# **Example 1:**
#
# ```python
# Input: n = 3, m = 2
# Output: 3
# ```
#
# **Explanation:** The following pairs satisfy conditions described in the statement: (1,2), (3,2), (2,1).
#
# **Example 2:**
#
# ```python
# Input: n = 1, m = 1
# Output: 0
# ```
#
# **Explanation:** No pairs satisfy the conditions described in the statement.
#
# **Constraints:**
#
# 1 <= n, m <= 105

# %%
class Solution:
    def flowerGame(self, n: int, m: int) -> int:
        """
        Calculates the number of flower pairings where one number is odd and the other is even.

        Algorithm:
        1. Count how many odd numbers exist from 1 to n.
        2. Count how many even numbers exist from 1 to m.
        3. Multiply odd(n) × even(m) → valid pairings.
        4. Multiply even(n) × odd(m) → valid pairings.
        5. Return the total number of valid pairings.
        """
        def count_odd(x: int) -> int:
            return (x + 1) // 2  # Equivalent to math.ceil(x / 2)

        def count_even(x: int) -> int:
            return x // 2  # Equivalent to math.floor(x / 2)

        odd_even = count_odd(n) * count_even(m)
        even_odd = count_even(n) * count_odd(m)
        return odd_even + even_odd

# %%
class Solution:
    def flowerGame(self, n: int, m: int) -> int:
        """
        Alice wins if the total number of flowers (x + y) is odd.
        This happens when one number is odd and the other is even.

        Algorithm:
        1. Count the number of odd and even numbers in [1, n] and [1, m].
        2. Case 1: x is odd, y is even → odd_n * even_m
        3. Case 2: x is even, y is odd → even_n * odd_m
        4. Total winning pairs = sum of both cases
        """
        # Count of odd numbers in [1, n]
        odd_n = (n + 1) // 2
        # Count of even numbers in [1, m]
        even_m = m // 2

        # Count of even numbers in [1, n]
        even_n = n // 2
        # Count of odd numbers in [1, m]
        odd_m = (m + 1) // 2

        return odd_n * even_m + even_n * odd_m

# %%
import math
class Solution:
    def flowerGame(self, n: int, m: int) -> int:
        """
        Calculates the number of flower pairings where one number is odd and the other is even.

        Algorithm:
        1. Count how many odd numbers exist from 1 to n.
        2. Count how many even numbers exist from 1 to m.
        3. Multiply odd(n) × even(m) → valid pairings.
        4. Multiply even(n) × odd(m) → valid pairings.
        5. Return the total number of valid pairings.
        """
        def count_odd(x: int) -> int:
			return math.ceil(x / 2)
        def count_even(x: int) -> int:
            return math.floor(x/2) # Equivalent to math.floor(x / 2)

        odd_even = count_odd(n) * count_even(m)
        even_odd = count_even(n) * count_odd(m)
        return odd_even + even_odd
