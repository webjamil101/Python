# %% [markdown]
# # 2918. Minimum Equal Sum of Two Arrays After Replacing Zeros
#
# # Medium
#
# You are given two arrays nums1 and nums2 consisting of positive integers.
#
# You have to replace all the 0's in both arrays with strictly positive integers such that the sum of elements of both arrays becomes equal.
#
# Return the minimum equal sum you can obtain, or -1 if it is impossible.
#
# # Example 1:
#
# ```
# Input: nums1 = [3,2,0,1,0], nums2 = [6,5,0]
# Output: 12
# Explanation: We can replace 0's in the following way:
# - Replace the two 0's in nums1 with the values 2 and 4. The resulting array is nums1 = [3,2,2,1,4].
# - Replace the 0 in nums2 with the value 1. The resulting array is nums2 = [6,5,1].
# Both arrays have an equal sum of 12. It can be shown that it is the minimum sum we can obtain.
# ```
#
# # Example 2:
#
# ```
# Input: nums1 = [2,0,2,0], nums2 = [1,4]
# Output: -1
# Explanation: It is impossible to make the sum of both arrays equal.
#
# ```
#
# # Constraints:
#
# - 1 <= nums1.length, nums2.length <= 105
# - 0 <= nums1[i], nums2[i] <= 106

# %%
from typing import List

class Solution:
    def min_sum_equal(self, nums1: List[int], nums2: List[int]) -> int:
        sum1 = sum(nums1)
        sum2 = sum(nums2)
        zero1 = nums1.count(0)
        zero2 = nums2.count(0)

        min_sum1 = sum1 + zero1
        min_sum2 = sum2 + zero2

        if zero1 == 0 and min_sum1 < sum2 + zero2:
            return -1
        if zero2 == 0 and min_sum2 < sum1 + zero1:
            return -1

        if zero1 == 0 and zero2 == 0:
            return sum1 if sum1 == sum2 else -1

        return max(min_sum1, min_sum2)

# %%
from typing import List

class Solution:
    def min_sum_equal(self, nums1: List[int], nums2: List[int]) -> int:
        sum1 = sum(nums1)
        sum2 = sum(nums2)
        zero1 = nums1.count(0)
        zero2 = nums2.count(0)

        min_sum1 = sum1 + zero1
        min_sum2 = sum2 + zero2

        if zero1 == 0 and min_sum1 < sum2 + zero2:
            return -1
        if zero2 == 0 and min_sum2 < sum1 + zero1:
            return -1

        if zero1 == 0 and zero2 == 0:
            return sum1 if sum1 == sum2 else -1

        return max(min_sum1, min_sum2)

# Edge and Test Cases
if __name__ == "__main__":
    sol = Solution()

    # Test Case 1: Basic case with zeros in both arrays
    nums1_1 = [1, 2, 0]
    nums2_1 = [3, 0]
    expected1 = 5
    output1 = sol.min_sum_equal(nums1_1, nums2_1)
    print(f"Input: nums1={nums1_1}, nums2={nums2_1}, Output: {output1}, Expected: {expected1} {'[PASS]' if output1 == expected1 else '[FAIL]'}")

    # Test Case 2: Zeros only in the first array
    nums1_2 = [1, 2, 0]
    nums2_2 = [3, 4]
    expected2 = 7
    output2 = sol.min_sum_equal(nums1_2, nums2_2)
    print(f"Input: nums1={nums1_2}, nums2={nums2_2}, Output: {output2}, Expected: {expected2} {'[PASS]' if output2 == expected2 else '[FAIL]'}")

    # Test Case 3: Zeros only in the second array
    nums1_3 = [1, 2]
    nums2_3 = [3, 0, 4]
    expected3 = 7
    output3 = sol.min_sum_equal(nums1_3, nums2_3)
    print(f"Input: nums1={nums1_3}, nums2={nums2_3}, Output: {output3}, Expected: {expected3} {'[PASS]' if output3 == expected3 else '[FAIL]'}")

    # Test Case 4: No zeros, sums are equal
    nums1_4 = [1, 2]
    nums2_4 = [3]
    expected4 = -1
    output4 = sol.min_sum_equal(nums1_4, nums2_4)
    print(f"Input: nums1={nums1_4}, nums2={nums2_4}, Output: {output4}, Expected: {expected4} {'[PASS]' if output4 == expected4 == -1 else '[FAIL]'}")

    # Test Case 5: No zeros, sums are not equal
    nums1_5 = [1, 2]
    nums2_5 = [4]
    expected5 = -1
    output5 = sol.min_sum_equal(nums1_5, nums2_5)
    print(f"Input: nums1={nums1_5}, nums2={nums2_5}, Output: {output5}, Expected: {expected5} {'[PASS]' if output5 == expected5 == -1 else '[FAIL]'}")

    # Test Case 6: One array has no zeros, minimum sum of the other is smaller
    nums1_6 = [1, 1]
    nums2_6 = [0, 0, 0, 5]
    expected6 = 7
    output6 = sol.min_sum_equal(nums1_6, nums2_6)
    print(f"Input: nums1={nums1_6}, nums2={nums2_6}, Output: {output6}, Expected: {expected6} {'[PASS]' if output6 == expected6 else '[FAIL]'}")

    # Test Case 7: One array has no zeros, minimum sum of the other is larger
    nums1_7 = [0, 0, 0, 5]
    nums2_7 = [1, 1]
    expected7 = 7
    output7 = sol.min_sum_equal(nums1_7, nums2_7)
    print(f"Input: nums1={nums1_7}, nums2={nums2_7}, Output: {output7}, Expected: {expected7} {'[PASS]' if output7 == expected7 else '[FAIL]'}")

    # Test Case 8: Both arrays have no zeros and sums are equal
    nums1_8 = [5]
    nums2_8 = [5]
    expected8 = 5
    output8 = sol.min_sum_equal(nums1_8, nums2_8)
    print(f"Input: nums1={nums1_8}, nums2={nums2_8}, Output: {output8}, Expected: {expected8} {'[PASS]' if output8 == expected8 else '[FAIL]'}")

    # Test Case 9: Both arrays have no zeros and sums are not equal
    nums1_9 = [5]
    nums2_9 = [6]
    expected9 = -1
    output9 = sol.min_sum_equal(nums1_9, nums2_9)
    print(f"Input: nums1={nums1_9}, nums2={nums2_9}, Output: {output9}, Expected: {expected9} {'[PASS]' if output9 == expected9 else '[FAIL]'}")

    # Test Case 10: Multiple zeros in both arrays
    nums1_10 = [0, 0, 1]
    nums2_10 = [0, 2, 0]
    expected10 = 4
    output10 = sol.min_sum_equal(nums1_10, nums2_10)
    print(f"Input: nums1={nums1_10}, nums2={nums2_10}, Output: {output10}, Expected: {expected10} {'[PASS]' if output10 == expected10 else '[FAIL]'}")

    # Test Case 11: One array is all zeros
    nums1_11 = [0, 0, 0]
    nums2_11 = [3]
    expected11 = 3
    output11 = sol.min_sum_equal(nums1_11, nums2_11)
    print(f"Input: nums1={nums1_11}, nums2={nums2_11}, Output: {output11}, Expected: {expected11} {'[PASS]' if output11 == expected11 else '[FAIL]'}")

    # Test Case 12: Both arrays are all zeros
    nums1_12 = [0, 0]
    nums2_12 = [0]
    expected12 = 2
    output12 = sol.min_sum_equal(nums1_12, nums2_12)
    print(f"Input: nums1={nums1_12}, nums2={nums2_12}, Output: {output12}, Expected: {expected12} {'[PASS]' if output12 == expected12 else '[FAIL]'}")

# %%
from typing import List

class Solution:
    def minSum(self, nums1: List[int], nums2: List[int]) -> int:
        sum1 = 0
        sum2 = 0
        zero1 = 0
        zero2 = 0

        temp_sum1 = 0
        temp_sum2 = 0

        for num in nums1:
            temp_sum1 += num
            if num == 0:
                zero1 += 1
                sum1 += 1
            else:
                sum1 += num

        for num in nums2:
            temp_sum2 += num
            if num == 0:
                zero2 += 1
                sum2 += 1
            else:
                sum2 += num

        if (sum1 < sum2 and zero1 == 0) or (sum2 < sum1 and zero2 == 0):
            return -1

        return max(sum1, sum2)

# %%
from typing import List

class Solution:
    def minSum(self, nums1: List[int], nums2: List[int]) -> int:
        sum1 = 0
        sum2 = 0
        zero1 = 0
        zero2 = 0

        temp_sum1 = 0
        temp_sum2 = 0

        for num in nums1:
            temp_sum1 += num
            if num == 0:
                zero1 += 1
                sum1 += 1
            else:
                sum1 += num

        for num in nums2:
            temp_sum2 += num
            if num == 0:
                zero2 += 1
                sum2 += 1
            else:
                sum2 += num

        if (sum1 < sum2 and zero1 == 0) or (sum2 < sum1 and zero2 == 0):
            return -1

        return max(sum1, sum2)

# Edge and Test Cases
if __name__ == "__main__":
    sol = Solution()

    # Test Case 1: Basic case with zeros in both arrays
    nums1_1 = [1, 2, 0]
    nums2_1 = [3, 0]
    expected1 = 6
    output1 = sol.minSum(nums1_1, nums2_1)
    print(f"Input: nums1={nums1_1}, nums2={nums2_1}, Output: {output1}, Expected: {expected1} {'[PASS]' if output1 == expected1 else '[FAIL]'}")

    # Test Case 2: Zeros only in the first array
    nums1_2 = [1, 2, 0]
    nums2_2 = [3, 4]
    expected2 = 7
    output2 = sol.minSum(nums1_2, nums2_2)
    print(f"Input: nums1={nums1_2}, nums2={nums2_2}, Output: {output2}, Expected: {expected2} {'[PASS]' if output2 == expected2 else '[FAIL]'}")

    # Test Case 3: Zeros only in the second array
    nums1_3 = [1, 2]
    nums2_3 = [3, 0, 4]
    expected3 = 7
    output3 = sol.minSum(nums1_3, nums2_3)
    print(f"Input: nums1={nums1_3}, nums2={nums2_3}, Output: {output3}, Expected: {expected3} {'[PASS]' if output3 == expected3 else '[FAIL]'}")

    # Test Case 4: No zeros, sums are equal
    nums1_4 = [1, 2]
    nums2_4 = [3]
    expected4 = -1
    output4 = sol.minSum(nums1_4, nums2_4)
    print(f"Input: nums1={nums1_4}, nums2={nums2_4}, Output: {output4}, Expected: {expected4} {'[PASS]' if output4 == expected4 == -1 else '[FAIL]'}")

    # Test Case 5: No zeros, sums are not equal
    nums1_5 = [1, 2]
    nums2_5 = [4]
    expected5 = -1
    output5 = sol.minSum(nums1_5, nums2_5)
    print(f"Input: nums1={nums1_5}, nums2={nums2_5}, Output: {output5}, Expected: {expected5} {'[PASS]' if output5 == expected5 == -1 else '[FAIL]'}")

    # Test Case 6: One array has no zeros, minimum sum of the other is smaller
    nums1_6 = [1, 1]
    nums2_6 = [0, 0, 0, 5]
    expected6 = 7
    output6 = sol.minSum(nums1_6, nums2_6)
    print(f"Input: nums1={nums1_6}, nums2={nums2_6}, Output: {output6}, Expected: {expected6} {'[PASS]' if output6 == expected6 else '[FAIL]'}")

    # Test Case 7: One array has no zeros, minimum sum of the other is larger
    nums1_7 = [0, 0, 0, 5]
    nums2_7 = [1, 1]
    expected7 = 7
    output7 = sol.minSum(nums1_7, nums2_7)
    print(f"Input: nums1={nums1_7}, nums2={nums2_7}, Output: {output7}, Expected: {expected7} {'[PASS]' if output7 == expected7 else '[FAIL]'}")

    # Test Case 8: Both arrays have no zeros and sums are equal
    nums1_8 = [5]
    nums2_8 = [5]
    expected8 = 5
    output8 = sol.minSum(nums1_8, nums2_8)
    print(f"Input: nums1={nums1_8}, nums2={nums2_8}, Output: {output8}, Expected: {expected8} {'[PASS]' if output8 == expected8 else '[FAIL]'}")

    # Test Case 9: Both arrays have no zeros and sums are not equal
    nums1_9 = [5]
    nums2_9 = [6]
    expected9 = -1
    output9 = sol.minSum(nums1_9, nums2_9)
    print(f"Input: nums1={nums1_9}, nums2={nums2_9}, Output: {output9}, Expected: {expected9} {'[PASS]' if output9 == expected9 else '[FAIL]'}")

    # Test Case 10: Multiple zeros in both arrays
    nums1_10 = [0, 0, 1]
    nums2_10 = [0, 2, 0]
    expected10 = 4
    output10 = sol.minSum(nums1_10, nums2_10)
    print(f"Input: nums1={nums1_10}, nums2={nums2_10}, Output: {output10}, Expected: {expected10} {'[PASS]' if output10 == expected10 else '[FAIL]'}")

    # Test Case 11: One array is all zeros
    nums1_11 = [0, 0, 0]
    nums2_11 = [3]
    expected11 = 3
    output11 = sol.minSum(nums1_11, nums2_11)
    print(f"Input: nums1={nums1_11}, nums2={nums2_11}, Output: {output11}, Expected: {expected11} {'[PASS]' if output11 == expected11 else '[FAIL]'}")

    # Test Case 12: Both arrays are all zeros
    nums1_12 = [0, 0]
    nums2_12 = [0]
    expected12 = 2
    output12 = sol.minSum(nums1_12, nums2_12)
    print(f"Input: nums1={nums1_12}, nums2={nums2_12}, Output: {output12}, Expected: {output12} {'[PASS]' if output12 == expected12 else '[FAIL]'}")
